# %%
# Importing modules
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import umap.umap_ as umap
import numba
import pyarrow.dataset as ds
import matplotlib.pylab as plt
from tqdm.notebook import tqdm
import hdbscan
from mpl_toolkits.axes_grid1 import make_axes_locatable
import corner
from sklearn.cluster import KMeans

# %%
# Pandas display options (personal preference)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)

# %%
# Matplotlib options
plt.rcParams['xtick.top'] = 'True'
plt.rcParams['ytick.right'] = 'True'
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.major.size'] = 6
plt.rcParams['xtick.minor.size'] = 3
plt.rcParams['ytick.major.size'] = 6
plt.rcParams['xtick.minor.visible'] = 'True'
plt.rcParams['ytick.minor.size'] = 3
plt.rcParams['ytick.minor.visible'] = 'True'
plt.rcParams['axes.linewidth'] = 1.2

plt.rcParams['figure.figsize'] = [10,8]
font = {'size'   : 20}
plt.rc('font', **font)

# %%
# Importing the G09 parquet file
dataset = ds.dataset("../../data/All_DDF/All_DDF_2p4.parquet", format="parquet")
table = dataset.to_table()

# Setting uberID as index
df = table.to_pandas().set_index('uberID')
df.index=df.index.astype('int64')

del dataset,table

# %%
# Getting rid of weird spaces in the class column
df=df.replace({'class': {'ambiguous ': 'ambiguous',
                         'star      ': 'star', 
                         'galaxy    ': 'galaxy', 
                         'artefact  ':'artefact'}})

# %%
# Making a number of cuts: magnitude, mask, starmask and removing artefacts
df=df[(df['mag_Zt']<22) & 
      (df['mask']==0) & 
      (df['starmask']==0) & 
      (df['class']!='artefact')&
      (df['duplicate']==0)
]

# %%
# Getting a 1/10 subset of the data (for the purpose of this tutorial)
# df=df[::10]

# %%
# Remove columns that have very high UMAP1 in the previous runs
df_bad = pd.read_csv('bad_UMAP1_to_remove.csv', index_col='uberID')
common_indices = df.index.intersection(df_bad.index)
df = df.drop(common_indices)

# %%
# Define the bands and their corresponding flux columns
bands = ['g', 'r', 'i', 'Z', 'Y', 'J', 'H', 'K']
tot_suffix = 't'
col_suffix = 'c'

# Loop through each band and calculate magnitudes for both 'tot' and 'col'
for band in bands:
    df[f'mag_{band}_tot'] = 8.9 - 2.5 * np.log10(df[f'flux_{band}t'])
    df[f'mag_{band}_col'] = 8.9 - 2.5 * np.log10(df[f'flux_{band}c'])
# Out:
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Generate lists for 'tot' and 'col' features
mag_tot_features = [f'mag_{band}_tot' for band in bands]
mag_col_features = [f'mag_{band}_col' for band in bands]

# Making a list of all features we will use for UMAP
features = mag_tot_features + mag_col_features + ['R50', 'R90', 'axrat']

# Colours list
colours = mag_col_features

# %%
# Removing all rows of the dataframe with NaN values
df_lim=df[features]

df=df.drop(df_lim[df_lim.isnull().any(axis=1)].index)

del df_lim

# %%
len(df)
# Out:
# 389044

# %%
# Making an empty array ready to put features
X = np.zeros((len(df), 39))

# %%
# Filling the first 36 features as each unique colours
l=0
for i in tqdm(range(len(colours))):
    for j in range(i+1,len(colours)):
        X[:,l]=(df[colours[i]] - df[colours[j]])
        l+=1
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# Filling the remaining features (total fluxes and size information)
X[:,28]=(df['mag_g_tot'])
X[:,29]=(df['mag_r_tot'])
X[:,30]=(df['mag_i_tot'])
X[:,31]=(df['mag_Z_tot'])
X[:,32]=(df['mag_Y_tot'])
X[:,33]=(df['mag_J_tot'])
X[:,34]=(df['mag_H_tot'])
X[:,35]=(df['mag_K_tot'])
X[:,36]=np.log10(df['R50'])
X[:,37]=df['R50']/df['R90']
X[:,38]=df['axrat']

# %%
# Scaling features to 0 mean and unit variance
X = StandardScaler().fit_transform(X)

# %%
# Applying UMAP to our features7
# These parameters have been fairly tuned, but there's definitely some room for some more tinkering
X_umap=umap.UMAP(
    n_neighbors=200,
    min_dist=0,
    n_components=10,
    random_state=42,
).fit_transform(X)
print('Done')
# Out:
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# Plotting the first two UMAP features
plt.scatter(X_umap[:,0],X_umap[:,1],s=2,linewidth=0)
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()

# %%
# Loop through UMAP components and assign them to the DataFrame
for i in range(10):
    df[f'umap{i+1}'] = X_umap[:, i]

# %%
# Defining labels as stars, galaxies, ambiguous
labels=np.unique(df['class'])
colors=['black','red','blue']

# %%
# Plotting UMAP 1 and UMAP 2 with baseline label as colour
for i in tqdm(range(len(labels))):
    plt.scatter(df[df['class']==labels[i]]['umap1'],
                df[df['class']==labels[i]]['umap2'],
                s=2,label=labels[i],c=colors[i],linewidth=0)

lgnd=plt.legend(frameon=False,title='Baseline label')

lgnd.legend_handles[0]._sizes = [50]
lgnd.legend_handles[1]._sizes = [50]
lgnd.legend_handles[2]._sizes = [50]
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')

plt.savefig('../plots/All_DDF/UMAP_no_u_baseline_All_DDF.jpg',bbox_inches='tight',dpi=100,facecolor='white')


plt.show()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# HDBSCAN clustering the UMAP feautre space
# min_samples should be probably 1000 when you apply to the entirety of the sample
clusterer = hdbscan.HDBSCAN(core_dist_n_jobs=-1,min_samples=350).fit(X_umap)
# Out:
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/ir-band1/1-research/venvs/umap_3-11/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# Setting the output of HDBSCAN into the dataframe
df['cluster_label']=clusterer.labels_

# %%
# Defining the unique cluster labels
clusterer_labels=np.unique(df['cluster_label'])

# %%
kmeans = KMeans(n_clusters = 2)
kmeans.fit(X_umap)
# Out:
# KMeans(n_clusters=2)

# %%
df['kmin_label']=kmeans.labels_

# %%
kmin_labels=np.unique(df['kmin_label'])

# %%
# Plotting UMAP 1 and UMAP 2 again with cluster label. Should correspond roughly with previous plot
for label in kmin_labels:
    plt.scatter(df[df['kmin_label'] == label]['umap1'],
                df[df['kmin_label'] == label]['umap2'],
                s=2, linewidth=0, label=str(label))

# plt.scatter(df[df['cluster_label']=='galaxy']['umap1'],
#             df[df['cluster_label']=='galaxy']['umap2'],
#             s=2,linewidth=0,label='galaxy',c='red')

# plt.scatter(df[df['cluster_label']=='star']['umap1'],
#             df[df['cluster_label']=='star']['umap2'],
            # s=2,linewidth=0,label='star',c='blue')
lgnd=plt.legend(frameon=False,title='Cluster label')

for i in range(len(kmin_labels)):
    lgnd.legend_handles[i]._sizes = [50]
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')

# plt.savefig('../plots/WD10/UMAP_u_cluster_WD10_kmin_label.jpg',bbox_inches='tight',dpi=100,facecolor='white')

plt.show()

# %%
# Corner plot of all 10 UMAP features

UMAPs = [f'UMAP {i}' for i in range(1, 11)]
umaps = [f'umap{i}' for i in range(1, 11)]

# Extracting data for each cluster label
X_clusters = {}
for label in clusterer_labels:
    X_clusters[label] = np.array(df[df['cluster_label'] == label][umaps])

# Define colors for each cluster label
cluster_colors = plt.cm.get_cmap('tab10', len(clusterer_labels))

data_kwargs = {'alpha': 0.5, 'markeredgewidth': 0, 'ms': 0.5}

font = {'size': 20}
plt.rc('font', **font)
plt.rcParams.update({
    'xtick.bottom': False,
    'xtick.top': False,
    'ytick.left': False,
    'ytick.right': False,
    'xtick.labelbottom': False,
    'ytick.labelleft': False,
})

fig = None
for label, color in zip(clusterer_labels, cluster_colors.colors):
    if X_clusters[label].shape[0] > len(UMAPs):  # Check if the number of samples is greater than the number of dimensions
        data_kwargs['color'] = color
        if fig is None:
            fig = corner.corner(X_clusters[label], plot_datapoints=True, plot_density=False,
                                plot_contours=False, labels=UMAPs, data_kwargs=data_kwargs,
                                labelpad=-0.2)
        else:
            corner.corner(X_clusters[label], plot_datapoints=True, plot_density=False,
                          plot_contours=False, labels=UMAPs, data_kwargs=data_kwargs, fig=fig,
                          labelpad=-0.2)

ndim = 10
axes = np.array(fig.axes).reshape((ndim, ndim))
for a in axes[np.triu_indices(ndim)]:
    a.remove()

# Adding legend
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=f'Cluster {label}')
           for label, color in zip(clusterer_labels, cluster_colors.colors)]

fig.legend(handles=handles, loc='center', bbox_to_anchor=(0.40, 0.75), title='Cluster label')
plt.savefig('../plots/UMAP_corner_all_DDF_cluster_label_no_u.jpg', bbox_inches='tight', dpi=200)
plt.show()
# Out:
# /tmp/ipykernel_374340/2284014270.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cluster_colors = plt.cm.get_cmap('tab10', len(clusterer_labels))

# %%
# For each HDBSCAN label, see how the baseline classification corresponds
for label in clusterer_labels:
    print(label,':')
    print('galaxy:',len(df[(df['cluster_label']==label) & (df['class']=='galaxy')]))
    print('star:',len(df[(df['cluster_label']==label) & (df['class']=='star')]))
    print('ambiguous:',len(df[(df['cluster_label']==label) & (df['class']=='ambiguous')]))
# Out:
# -1 :
# galaxy: 1829
# star: 263
# ambiguous: 343
# 0 :
# galaxy: 305038
# star: 430
# ambiguous: 6806
# 1 :
# galaxy: 10391
# star: 44167
# ambiguous: 19777

# %%
# For each HDBSCAN label, see how the baseline classification corresponds
for label in kmin_labels:
    print(label,':')
    print('galaxy:',len(df[(df['kmin_label']==label) & (df['class']=='galaxy')]))
    print('star:',len(df[(df['kmin_label']==label) & (df['class']=='star')]))
    print('ambiguous:',len(df[(df['kmin_label']==label) & (df['class']=='ambiguous')]))
# Out:
# 0 :
# galaxy: 307399
# star: 639
# ambiguous: 7607
# 1 :
# galaxy: 9859
# star: 44221
# ambiguous: 19319

# %%
# Manually defining the HDBSCAN outputs to galaxy or star, based on the previous cell
df['kmin_label']=df['kmin_label'].replace([0], 'galaxy')
df['kmin_label']=df['kmin_label'].replace([1], 'star')
# df['cluster_label']=df['cluster_label'].replace([-1], 'galaxy')

# %%
df['cluster_label']=df['kmin_label']

# %%
# Plotting UMAP 1 and UMAP 2 again with cluster label. Should correspond roughly with previous plot
plt.scatter(df[df['cluster_label']=='galaxy']['umap1'],
            df[df['cluster_label']=='galaxy']['umap2'],
            s=2,linewidth=0,label='Galaxy',c='red')

plt.scatter(df[df['cluster_label']=='star']['umap1'],
            df[df['cluster_label']=='star']['umap2'],
            s=2,linewidth=0,label='Star',c='blue')

lgnd=plt.legend(frameon=False,title='Cluster label')

lgnd.legend_handles[0]._sizes = [50]
lgnd.legend_handles[1]._sizes = [50]
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')

plt.savefig('../plots/All_DDF/All_DDF_UMAP_no_u_cluster.jpg',bbox_inches='tight',dpi=100,facecolor='white')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Plotting UMAP 1 and UMAP 2 again with cluster label. Should correspond roughly with previous plot
# ----> 2 plt.scatter(df[df['cluster_label']=='galaxy']['umap1'],
#       3             df[df['cluster_label']=='galaxy']['umap2'],
#       4             s=2,linewidth=0,label='Galaxy',c='red')
#       6 plt.scatter(df[df['cluster_label']=='star']['umap1'],
#       7             df[df['cluster_label']=='star']['umap2'],
#       8             s=2,linewidth=0,label='Star',c='blue')
#      10 lgnd=plt.legend(frameon=False,title='Cluster label')
#
# NameError: name 'plt' is not defined

# %%
#Saving labels
df.to_csv('../../data/All_DDF/All_DDF_no_u.csv')

# %%
df
# Out:
#                                           FrameName  FrameID   segID     xmax  \
# uberID
# 9581275900715    waves_postprocessed_10.0_-42.5.rds    958.0     102  12758.5
# 9580381200351    waves_postprocessed_10.0_-42.5.rds    958.0     126   3811.5
# 9580803300964    waves_postprocessed_10.0_-42.5.rds    958.0     144   8032.5
# 9581349700322    waves_postprocessed_10.0_-42.5.rds    958.0     148  13496.5
# 9580791000958    waves_postprocessed_10.0_-42.5.rds    958.0     171   7909.5
# ...                                             ...      ...     ...      ...
# 150020586706708   waves_postprocessed_149.5_1.2.rds  15002.0  105281   5866.5
# 150020268407025   waves_postprocessed_149.5_1.2.rds  15002.0  106826   2683.5
# 150021082512858   waves_postprocessed_149.5_1.2.rds  15002.0  107842  10824.5
# 150020168207166   waves_postprocessed_149.5_1.2.rds  15002.0  108385   1681.5
# 150020752708619   waves_postprocessed_149.5_1.2.rds  15002.0  124976   7526.5
#
#                     ymax       censep       RAcen     Deccen       RAmax  \
# uberID
# 9581275900715      714.5  8550.818440    9.343646 -43.021880    9.343656
# 9580381200351      350.5  6311.182536   10.363559 -43.053557   10.363609
# 9580803300964      963.5  5544.511250    9.882306 -43.002976    9.882352
# 9581349700322      321.5  9370.770139    9.259132 -43.054142    9.259157
# 9580791000958      957.5  5510.661848    9.896392 -43.003485    9.896366
# ...                  ...          ...         ...        ...         ...
# 150020586706708   6707.5   608.894901  149.595410   1.175170  149.594478
# 150020268407025   7024.5  3607.772304  149.859623   1.202512  149.859783
# 150021082512858  12857.5  8113.721033  149.181190   1.687652  149.181168
# 150020168207166   7165.5  4616.276638  149.943258   1.213657  149.943299
# 150020752708619   8618.5  2765.863337  149.455956   1.334612  149.456113
#
#                     Decmax    RAGAIA_r      RAGAIA    DecGAIA  DecGAIA_r  \
# uberID
# 9581275900715   -43.021902    9.343692    9.343692 -43.021909 -43.021909
# 150021082512858 -1.015328  6.073888  2.902774  5.873207  3.290978  5.820378
# 150020168207166  0.181117  5.932018  1.856164  6.482868  2.589790  6.418262
# 150020752708619 -1.057993  6.246886  4.580232  5.893373  3.117102  5.821626
#
#                     umap7     umap8     umap9    umap10 cluster_label  \
# uberID
# 9581275900715    8.277063  5.855236  3.763412  7.104206          star
# 9580381200351    7.828861  5.965283  3.796903  7.288033          star
# 9580803300964    7.624912  5.993060  3.826331  7.365678          star
# 9581349700322    7.852513  5.961969  3.787576  7.271113          star
# 9580791000958    7.603266  5.995957  3.828583  7.372553          star
# ...                   ...       ...       ...       ...           ...
# 150020586706708  4.170596  7.495205  3.321827  7.560244        galaxy
# 150020268407025  5.090540  6.850739  2.679547  7.504241        galaxy
# 150021082512858  5.034897  7.161354  2.349980  7.527706        galaxy
# 150020168207166  5.025216  7.417738  3.116625  7.482512        galaxy
# 150020752708619  5.091133  7.309541  2.459316  7.513593        galaxy
#
#                 kmin_label
# uberID
# 9581275900715         star
# 9580381200351         star
# 9580803300964         star
# 9581349700322         star
# 9580791000958         star
# ...                    ...
# 150020586706708     galaxy
# 150020268407025     galaxy
# 150021082512858     galaxy
# 150020168207166     galaxy
# 150020752708619     galaxy
#
# [389044 rows x 162 columns]

# %%
# Importing the G09 parquet file
dataset = ds.dataset("../../data/All_DDF/All_DDF_2p4.parquet", format="parquet")
table = dataset.to_table()

# Setting uberID as index
df_untuched = table.to_pandas().set_index('uberID')
df_untuched.index=df_untuched.index.astype('int64')

del dataset,table

# %%
df_untuched
# Out:
#                                          FrameName  FrameID  segID     xmax  \
# uberID
# 11580600903055  waves_postprocessed_11.3_-42.5.rds   1158.0      1   6008.5
# 11581308200245  waves_postprocessed_11.3_-42.5.rds   1158.0      2  13081.5
# 11580274900396  waves_postprocessed_11.3_-42.5.rds   1158.0      3   2748.5
# 11580501502826  waves_postprocessed_11.3_-42.5.rds   1158.0      4   5014.5
# 11580655906443  waves_postprocessed_11.3_-42.5.rds   1158.0      5   6558.5
# ...                                            ...      ...    ...      ...
# 7550633609977    waves_postprocessed_7.3_-45.5.rds    755.0  95403   6335.5
# 7550830810346    waves_postprocessed_7.3_-45.5.rds    755.0  95431   8307.5
# 7550894212339    waves_postprocessed_7.3_-45.5.rds    755.0  96102   8941.5
# 7550792809489    waves_postprocessed_7.3_-45.5.rds    755.0  97414   7927.5
# 7550529309743    waves_postprocessed_7.3_-45.5.rds    755.0  97681   5292.5
#
#                    ymax       censep      RAcen     Deccen      RAmax  \
# uberID
# 11580600903055   3054.5  3145.504093  11.462416 -42.828601  11.462660
# 11581308200245    244.5  9101.278427  10.656416 -43.060561  10.656406
# 11580274900396    395.5  6745.614650  11.834693 -43.049147  11.834796
# 11580501502826   2825.5  3569.672394  11.575842 -42.847673  11.575672
# 11580655906443   6442.5   440.454311  11.400219 -42.547424  11.399939
# ...                 ...          ...        ...        ...        ...
# 7550633609977    9976.5  3784.627459   7.378719 -45.252146   7.378658
#                 flux_gt_uncorrected  flux_err_gt_uncorrected   flux_rt  \
# uberID
# 11580600903055             0.002553             4.969019e-06  0.004384
# 11581308200245             0.003925             9.018588e-06  0.005917
# 11580274900396                  NaN             9.727545e-07       NaN
# 11580501502826             0.004227             7.568702e-06  0.007294
# 11580655906443             0.010024             7.018165e-05  0.015261
# ...                             ...                      ...       ...
# 7550633609977                   NaN             1.362913e-07       NaN
# 7550830810346                   NaN             3.302843e-07       NaN
# 7550894212339                   NaN             1.375247e-07       NaN
# 7550792809489                   NaN             2.410188e-07       NaN
# 7550529309743                   NaN             1.874146e-07       NaN
#
#                  flux_err_rt  flux_rt_uncorrected  flux_err_rt_uncorrected  \
# uberID
# 11580600903055  5.930013e-06             0.004226             5.716673e-06
# 11581308200245  4.964686e-06             0.005761             4.834365e-06
# 11580274900396  1.054398e-06                  NaN             1.024597e-06
# 11580501502826  3.238807e-05             0.007031             3.121958e-05
# 11580655906443  1.214877e-04             0.014748             1.174052e-04
# ...                      ...                  ...                      ...
# 7550633609977   1.052540e-07                  NaN             1.015611e-07
# 7550830810346   2.546100e-07                  NaN             2.461203e-07
# 7550894212339   1.054389e-07                  NaN             1.024802e-07
# 7550792809489   1.871072e-07                  NaN             1.796017e-07
# 7550529309743   1.442769e-07                  NaN             1.396570e-07
#
#                  flux_it   flux_err_it  flux_it_uncorrected  \
# uberID
# 11580600903055  0.006767  7.969752e-06             0.006576
# 11581308200245  0.009052  2.483929e-05             0.008866
# 11580274900396       NaN  3.998550e-06                  NaN
# 11580501502826  0.011779  2.114081e-05             0.011446
# 11580655906443  0.032527  1.143933e-04             0.031670
# ...                  ...           ...                  ...
# 7550633609977        NaN  5.517656e-07                  NaN
# 7550830810346        NaN  1.335250e-06                  NaN
# 7550894212339        NaN  5.536116e-07                  NaN
# 7550792809489        NaN  9.797402e-07                  NaN
# 7550529309743        NaN  7.568570e-07                  NaN
#
#                 flux_err_it_uncorrected   flux_Zt   flux_err_Zt  \
# uberID
# 11580600903055             7.744769e-06  0.059002  2.729970e-05
# 11581308200245             2.432823e-05  0.062477  2.236151e-05
# 11580274900396             3.909950e-06  0.058141  6.094097e-05
# 11580501502826             2.054232e-05  0.078172  1.545605e-04
# 11580655906443             1.113777e-04  0.162347  4.712941e-04
# ...                                 ...       ...           ...
# 7550633609977              5.365768e-07  0.000002  2.383020e-07
# 7550830810346              1.300325e-06  0.000016  1.136400e-06
# 7550894212339              5.414328e-07  0.000002  4.164458e-07
# 7550792809489              9.488876e-07  0.000004  5.858320e-07
# 7550529309743              7.378485e-07  0.000003  2.987559e-07
#
#                 flux_Zt_uncorrected  flux_err_Zt_uncorrected   flux_Yt  \
# uberID
# 11580600903055             0.057751             2.672105e-05  0.080600
# 11581308200245             0.061513             2.201640e-05  0.075170
# 11580274900396             0.057175             5.992786e-05  0.055921
# 11580501502826             0.076510             1.512751e-04  0.110659
# 11580655906443             0.159134             4.619678e-04  0.193266
# ...                             ...                      ...       ...
# 7550633609977              0.000002             2.333770e-07  0.000008
#
#                 flux_err_Kt  flux_Kt_uncorrected  flux_err_Kt_uncorrected  \
# uberID
# 11580600903055     0.000074         5.893666e-02                 0.000074
# 11581308200245     0.000063         4.929323e-02                 0.000063
# 11580274900396     0.000074         4.585244e-02                 0.000073
# 11580501502826     0.000121         7.075572e-02                 0.000120
# 11580655906443     0.000587         1.555525e-01                 0.000585
# ...                     ...                  ...                      ...
# 7550633609977      0.000001        -2.338883e-06                 0.000001
# 7550830810346      0.000004         5.607825e-06                 0.000004
# 7550894212339      0.000002        -9.028047e-08                 0.000002
# 7550792809489      0.000002         3.095760e-06                 0.000002
# 7550529309743      0.000002         4.020334e-06                 0.000002
#
#                     flux_W1t  flux_err_W1t  flux_W1t_uncorrected  \
# uberID
# 11580600903055  3.035076e-02  2.141536e-05          3.026658e-02
# 11581308200245  2.483009e-02  1.822757e-05          2.478007e-02
# 11580274900396  1.733895e-02  6.930500e-06          1.730131e-02
# 11580501502826  8.209291e-02  4.312043e-05          8.186455e-02
# 11580655906443  2.161888e-01  1.531131e-04          2.156293e-01
# ...                      ...           ...                   ...
# 7550633609977   2.077368e-08  3.214802e-08          2.071751e-08
# 7550830810346   3.883323e-07  1.157476e-07          3.873352e-07
# 7550894212339   6.682265e-06  1.542405e-07          6.667863e-06
# 7550792809489   9.289720e-07  1.199210e-07          9.260933e-07
# 7550529309743   7.516807e-06  4.804211e-08          7.498285e-06
#
#                 flux_err_W1t_uncorrected      flux_W2t  flux_err_W2t  \
# uberID
# 11580600903055              2.135596e-05  1.618351e-02  1.657543e-05
# 11581308200245              1.819085e-05  1.272481e-02  3.704278e-05
# 11580274900396              6.915453e-06  9.066627e-03  1.638346e-05
# 11580501502826              4.300049e-05  4.204498e-02  2.548936e-05
# 11580655906443              1.527168e-04  1.381047e-01  1.076431e-04
# ...                                  ...           ...           ...
# 7550633609977               3.206110e-08 -5.133692e-07  6.062858e-08
# 7550830810346               1.154504e-07  6.475054e-07  1.651319e-07
# 7550894212339               1.539081e-07  1.369591e-05  4.042086e-07
# 7550792809489               1.195494e-07 -7.497038e-07  1.304532e-07
# 7550529309743               4.792372e-08  6.904144e-06  9.319404e-08
#
#                 flux_W2t_uncorrected  flux_err_W2t_uncorrected   flux_uc  \
# uberID
# 11580600903055          1.615232e-02              1.654349e-05  0.002529
# 11581308200245          1.270700e-02              3.699093e-05  0.006875
# 11580274900396          9.052951e-03              1.635875e-05       NaN
# 11580501502826          4.196372e-02              2.544010e-05  0.001193
# 11580655906443          1.378563e-01              1.074496e-04  0.004945
# ...                              ...                       ...       ...
# 7550633609977          -5.124047e-07              6.051467e-08       NaN
# 7550830810346           6.463502e-07              1.648373e-07       NaN
# 7550894212339           1.367540e-05              4.036034e-07       NaN
# 7550792809489          -7.480895e-07              1.301723e-07       NaN
# 7550529309743           6.892323e-06              9.303448e-08       NaN
#
#                  flux_err_uc   flux_gc   flux_err_gc   flux_rc   flux_err_rc  \
# uberID
